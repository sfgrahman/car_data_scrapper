# %%
brand_name = [
    "9ff",
    "ABT Sportsline",
    "AC Cars",
    "ADK",
    "AGCO",
    "AIL",
    "AITO",
    "AM General",
    "AMC",
    "AMI",
    "ARO",
    "ASA",
    "AUDI",
    "Abarth",
    "Acadian",
    "Acura",
    "Adam Motor Company",
    "Afeela",
    "Agrale",
    "Aion",
    "Aiways",
    "Aixam",
    "Ajax",
    "Alatac",
    "Albion",
    "Alesbury",
    "Alfa Romeo",
    "Allard",
    "Almac",
    "Alpha Sports",
    "Alpina",
    "Alpine",
    "Alta",
    "Alternative Cars",
    "Alvis",
    "Amati Cars",
    "Amazonas Motos Especiais",
    "Amazonas Motos Especiais (AME)",
    "American Simplex",
    "Amherst",
    "Amilcar",
    "Amphicar",
    "Amplex",
    "Anadol",
    "Anasagasti",
    "Andino",
    "Anglo-Dane",
    "Anteros",
    "Anziel",
    "Apal",
    "Arash",
    "Arcfox",
    "Arcimoto",
    "Argentina",
    "Ariel",
    "Armstrong Siddeley",
    "Arrinera",
    "Arrival",
    "Artega",
    "Ascari",
    "Ascort",
    "Ashok Leyland",
    "Asia",
    "Aspa",
    "Aspark",
    "Aspid",
    "Aston Martin",
    "Astra",
    "Asüna",
    "Atlas Honda",
    "Attica",
    "Auburn",
    "Audi",
    "Aurica",
    "Aurus Motors",
    "Austin-Healey",
    "Australian Six",
    "Australis",
    "Austro-Daimler",
    "Austro-Tatra",
    "Auto Avio Costruzioni",
    "Auto Union",
    "Auto and motor shows",
    "Auto-Mixte",
    "AutoLatina",
    "Autobianchi",
    "Autokinitoviomihania Ellados",
    "Automeccanica",
    "Automobile manufacturers",
    "Automobile sales by model",
    "Automotive design",
    "Automotive engineering",
    "Autozam",
    "Avatr Technology",
    "Avia",
    "Avibrás",
    "AzSamand",
    "BAIC Group",
    "BET",
    "BMW",
    "BMW M",
    "BYD",
    "BYD Bus",
    "Baby-Brousse",
    "Bahman",
    "Bajaj Auto",
    "Balkania",
    "Ballot",
    "Bangladesh",
    "Baojun",
    "Baolong",
    "Beattie",
    "Beaumont",
    "Beijing",
    "Beijing Automobile Works",
    "Beijing Off-road",
    "BelAZ",
    "BelGee",
    "Belarus",
    "Benelli",
    "Bentley",
    "Berkeley",
    "Berliet",
    "Bernardini",
    "Bertone",
    "Bestune",
    "Biamax",
    "Birchfield",
    "Birkin",
    "Bitter",
    "Bizzarrini",
    "Bjering",
    "Blade",
    "Bollinger Motors",
    "Bolloré",
    "Bolwell",
    "Bombardier Recreational Products",
    "Bond",
    "Borgward",
    "Borland Racing Developments",
    "Brabus",
    "Brasil & Movimento",
    "Brasinca",
    "Brazil",
    "Bremach",
    "Brems",
    "Bricklin",
    "Briggs Automotive Company (BAC)",
    "Bristol",
    "British Salmson",
    "Brock",
    "Brooks",
    "Buchanan",
    "Buckle",
    "Buckler",
    "Buddy",
    "Bufori",
    "Bugatti",
    "Buick",
    "Bulgaralpine",
    "Bulgaria",
    "Bulgarrenault",
    "Bullet",
    "Bus manufacturers",
    "Bush Ranger",
    "Busscar",
    "Byton",
    "C.AR",
    "CAMI",
    "CFMoto",
    "CMC",
    "CT&T",
    "Cadillac",
    "Caldwell Vale",
    "Callaway",
    "Campagna",
    "Canada",
    "Canadian",
    "Canadian Electric Vehicles",
    "Canadian Motor",
    "Candia",
    "Canoo",
    "Carbuss",
    "Carlton",
    "Casalini",
    "Category",
    "Caterham Cars",
    "Caterpillar Brasil",
    "Ceer Motors",
    "Chambers Motors",
    "Chamonix",
    "Chamonix Athos",
    "Chang'an Motors",
    "Changan",
    "Changan Nevo",
    "Changfeng Motor",
    "Changhe",
    "Chatenet",
    "Checker",
    "Cheetah",
    "Chenard-Walcker",
    "Chery",
    "Chery New Energy",
    "Chevrolet",
    "Chevron",
    "ChienThang",
    "China",
    "Chinkara Motors",
    "Chrysler",
    "Chrysler Europe",
    "Cisitalia",
    "Citroën",
    "CityEl",
    "Cizeta",
    "Clan",
    "Clinton",
    "Cobra",
    "Coda",
    "Colonial",
    "Colt",
    "Comarth",
    "Comil",
    "Companhia Industrial Santa Matilde",
    "Cord",
    "Countries by motor vehicle production",
    "Countries by vehicles per capita",
    "Covini",
    "Credo",
    "Croatia",
    "Crosley",
    "Crossley",
    "Crowther",
    "Csepel",
    "Csonka",
    "Cupra",
    "Custoca",
    "Czech Republic",
    "Czinger",
    "DAF",
    "DAF Trucks",
    "DB",
    "DFSK",
    "DIM",
    "DKW",
    "DOK-ING",
    "DR",
    "DS",
    "Dacia",
    "Dadi",
    "Daewoo",
    "Daewoo Automobile S.A.",
    "Dafra Motos",
    "Daihatsu",
    "Daimler",
    "Dansk",
    "Dardo",
    "Darracq",
    "Datsun",
    "David Brown",
    "Dayang",
    "De Dion-Bouton",
    "De Joux",
    "De Tomaso",
    "De Wandre",
    "De la Chapelle",
    "DeLorean Motor Company",
    "DeSoto",
    "Debadging",
    "Deepal",
    "Delage",
    "Delahaye",
    "Delecroix",
    "Dellow",
    "Dennison",
    "Denza",
    "Denzel",
    "Derways",
    "Detroit Electric",
    "Devaux",
    "Devel Motors",
    "Devon",
    "Devrim",
    "Dewan Farooque Motors",
    "Diana",
    "Diar",
    "Dina",
    "Distribuidora de Automóveis, Caminhões e Ônibus Nacionais",
    "Dodge",
    "Dominion Motors Frontenac",
    "Dongfeng",
    "Dongfeng Fengshen",
    "Dongfeng Nammi",
    "Donkervoort",
    "Drako Motors",
    "Drive time",
    "Ducati do Brasil",
    "Duesenberg",
    "Durant",
    "Dutton",
    "E-Z-GO",
    "EBIAM",
    "ELVO",
    "Eagle",
    "Edison Motors",
    "Edran",
    "Edsel",
    "Effa Motors",
    "Egypt",
    "Eicher Motors",
    "El Car",
    "Elcat",
    "Electric Raceabout",
    "Elfin Cars",
    "Elio Motors",
    "Elva",
    "Enfield",
    "Engenheiros Especializados",
    "Eniak",
    "Envoy",
    "Epic",
    "Equus Automotive",
    "ErAZ",
    "Esemka",
    "Etox",
    "Eunos",
    "Eurostar Automobilwerk",
    "Everson",
    "Everus",
    "Excelsior",
    "Exeed",
    "Exlantix",
    "Eysink",
    "F&M",
    "FAP",
    "FAW Pakistan",
    "FAW Tianjin (Xiali)",
    "FCA Srbija",
    "FNM",
    "FNM Fábrica Nacional de Motores",
    "FSO",
    "Fabral",
    "Facel Vega",
    "Facelift",
    "Fairthorpe",
    "Falcon",
    "Fangchengbao",
    "Faraday",
    "Farboud Limited",
    "Farus",
    "Fejes",
    "Felber Autoroller",
    "Fengon",
    "Ferrari",
    "Ferrari Polski",
    "Fiat",
    "Fiat Chrysler Canada",
    "Finch Restorations",
    "Firefly",
    "First Automotive Works",
    "Fisker",
    "Flaid",
    "Foday",
    "Force Motors",
    "Ford",
    "Ford Canada",
    "Ford Romania",
    "Ford Union",
    "Ford-Balt",
    "Ford-Werke",
    "Formosa",
    "Foton",
    "Fraser",
    "Frazer",
    "Frazer Nash",
    "Freightliner",
    "Frontenac",
    "GAC Group",
    "GAC Ireland",
    "GAZ",
    "GM Korea",
    "GMC",
    "GMK",
    "GMB",
    "GR",
    "GSM",
    "GTA Motor",
    "Ganja Auto Plant",
    "Gareau",
    "Gatter",
    "Geely (Jili)",
    "Geely Auto",
    "Geely Galaxy",
    "Geely Geometry",
    "Geijer",
    "Gemballa",
    "General Motors",
    "General Motors Canada",
    "Genesis",
    "Geo",
    "Gerard Farre",
    "Germain",
    "Germany",
    "Ghandhara Industries",
    "Ghandhara Nissan",
    "Giannini",
    "Gilbern",
    "Gillet",
    "Ginetta",
    "Giocattolo",
    "Giottiline",
    "Girardin Minibus",
    "Glas",
    "Glossary",
    "Gobron-Brillié",
    "Goggomobil",
    "Goliath",
    "Gonow",
    "Gordon Murray Automotive",
    "Gordon-Keeble",
    "Granu",
    "Gray-Dort",
    "Great Wall Motors",
    "Grecav",
    "GreenPower",
    "Grofri",
    "Grupo CNH Industrial",
    "Grupo Caoa",
    "Gräf & Stift",
    "Gurgel",
    "HSV",
    "HTT Automobile",
    "Hafei",
    "Haima Automobile",
    "Hansa",
    "Harley-Davidson",
    "Hartnett",
    "Haval",
    "Hawtai (Huatai)",
    "Hayden Dart",
    "Heavy Industries Taxila",
    "Heinkel",
    "Hennessey",
    "Hercules",
    "Heron",
    "Hi-Tech",
    "Hicom",
    "Hillman",
    "Hindustan Motors",
    "Hino",
    "Hino Motors",
    "Hinopak",
    "Hispano Suiza",
    "Hispano-Argentina",
    "History of the automobile",
    "History of the internal combustion engine",
    "Ineos Automotive",
    "Innocenti",
    "Innoson Vehicle Manufacturing",
    "Inokom",
    "Intermeccanica",
    "Invacar",
    "Invicta",
    "Iran",
    "Iran Khodro",
    "Ireland",
    "Iros",
    "Isdera",
    "Iso",
    "Isuzu",
    "Italdesign",
    "Italy",
    "Iveco",
    "Izh",
    "Izuogu",
    "J-Bus",
    "JAC Motors",
    "JMC",
    "JPX Indústria e Comércio",
    "Jacer",
    "Jaecoo",
    "Jaguar",
    "Jaguar e Land Rover Brasil",
    "Jawa",
    "Jeecy-Vea",
    "Jeep",
    "Jehle",
    "Jensen",
    "Jetour",
    "Jiangling",
    "Jinbei",
    "John Deere",
    "Jonway",
    "Jordan",
    "Joss Developments",
    "Jowett",
    "Juwel",
    "Jösse Car",
    "K-1 Engineering",
    "KTM",
    "Kaditcha",
    "Kaipan",
    "Kaiser",
    "KamAZ",
    "Kantanka",
    "Karenjy",
    "Karma",
    "Karmann-Ghia",
    "Karosa",
    "Kawasaki",
    "Kawasaki Motors",
    "Keating Supercars",
    "Kenworth",
    "Kenya",
    "Keraboss",
    "Khodro Kaveer",
    "Kia",
    "Kia Lucky Motors",
    "Kiira",
    "King Long",
    "Kioleides",
    "Kish Khodro",
    "Koenigsegg",
    "Komatsu",
    "Kongsberg",
    "Korres",
    "Korvensuu",
    "KrAZ",
    "Krampers",
    "Kymco",
    "LIAZ",
    "LaFayette",
    "LaSalle",
    "Lada",
    "Lafer",
    "Lagonda",
    "Lamborghini",
    "Lanchester",
    "Lancia",
    "Land Rover",
    "Landwind",
    "Laraki",
    "Lea-Francis",
    "Leapmotor",
    "Leitch",
    "Lexus",
    "Leyland",
    "Li Auto",
    "Libelle",
    "Lifan",
    "Ligier",
    "Lincoln",
    "Lion Bus",
    "Litex Motors",
    "Lloyd",
    "Lloyd-Hartnett",
    "Lobini",
    "Local",
    "Lohner–Porsche",
    "London Electric Vehicle Company",
    "London Six",
    "Lonsdale",
    "Lorraine-Dietrich",
    "Lotec",
    "Lotus",
    "Lotus-Cortina",
    "Lucid",
    "Luxeed",
    "Luxgen",
    "Lynk & Co",
    "Lyons",
    "M-Hero",
    "MAN",
    "MAVA-Renault",
    "MBM",
    "MEBEA",
    "MG",
    "MG JW Automobile",
    "MG Motor",
    "MTX / Metalex",
    "MVM",
    "MW Motors",
    "Mack",
    "Maextro",
    "Mafersa",
    "Magirus",
    "Magna Steyr",
    "Magneti Marelli",
    "Mahindra",
    "Mahindra & Mahindra Limited",
    "Malaysia",
    "Manic GT",
    "Marauder",
    "Marcopolo",
    "Marlborough",
    "Marmon",
    "Marquette",
    "Marussia",
    "Maruti",
    "Maruti Suzuki",
    "Mascarello",
    "Maserati",
    "Massey Ferguson",
    "Master",
    "Mastretta",
    "Mathis",
    "Matra",
    "Maxus",
    "Maxwell",
    "Maybach",
    "Mazda",
    "Mazzanti",
    "McLaren",
    "McLaughlin",
    "McRae",
    "Meeussen",
    "Melex",
    "Melkus",
    "Mercedes-Benz",
    "Mercer",
    "Mercury",
    "Merkur",
    "Messerschmitt",
    "Meteor",
    "Metropolitan",
    "Micro",
    "Microcar",
    "Microenterprise",
    "Midas",
    "Miesse",
    "Millat Tractors",
    "Minerva",
    "Minetti Sports Cars",
    "Minor automotive manufacturing groups",
    "Minsk Automobile Plant",
    "Mistral",
    "Mitsubishi",
    "Mitsubishi Fuso",
    "Mitsuoka",
    "Mobius",
    "Monarch",
    "Monteverdi",
    "Moon",
    "Moose Jaw Standard",
    "Morattab",
    "Morgan",
    "Morocco",
    "Morris",
    "Moskvich",
    "Moskvitch",
    "Mosler",
    "Motor vehicle",
    "Nio",
    "Nissan",
    "Nobe",
    "Noble",
    "Norsk",
    "Nota",
    "Nova Bus",
    "Novoplan",
    "Ntekop",
    "Nu Ride Inc.",
    "Nyayo",
    "O.S.C.A.",
    "ORA",
    "Oakland",
    "Obvio!",
    "Oldsmobile",
    "Oltcit",
    "Omoda",
    "Onvo",
    "Opel",
    "Optimal Energy",
    "Orca",
    "Organisation Internationale des Constructeurs d'Automobiles",
    "Oshan",
    "PGO",
    "PRB",
    "PVP Karting",
    "Packard",
    "Pagani",
    "Pak Suzuki",
    "Pakistan",
    "Pan-Car",
    "Panhard",
    "Panhard et Levassor",
    "Panoz",
    "Panther",
    "Paramount",
    "Pars Khodro",
    "Paykan",
    "Peel Engineering Company",
    "Peerless",
    "Pegaso",
    "Pellandini",
    "Perana",
    "Perodua",
    "Peterbilt",
    "Peugeot",
    "Philippines",
    "Piaggio",
    "Pieper",
    "Pindad",
    "Pininfarina",
    "Pipe",
    "Pirin-Fiat",
    "Plymouth",
    "Poland",
    "Polaris",
    "Polarsun Automobile",
    "Polestar",
    "Polski Fiat",
    "Pontiac",
    "Porsche",
    "Portaro",
    "Praga",
    "Pragoti",
    "Premier",
    "Prevost",
    "Prince",
    "Prince DFSK",
    "Princess",
    "Protea",
    "Proto",
    "Proton",
    "Puch",
    "Puma",
    "Puma Automóveis",
    "Puma Clubman",
    "Purvis Eureka",
    "Pyeonghwa Motors",
    "Python",
    "Qoros",
    "Queen",
    "Qvale",
    "RAESR",
    "RW",
    "Racefab",
    "Radical",
    "Ram Trucks",
    "Rambler",
    "Ranger",
    "Rebadging",
    "Record",
    "Redline",
    "Reliant",
    "Renault",
    "Renault Samsung",
    "Renault Trucks",
    "Rengsjöbilen",
    "Replicar Hellas",
    "Reva",
    "Revoz",
    "Rezvani",
    "Riley",
    "Rimac",
    "Rinspeed",
    "Rising Auto",
    "Rivian",
    "Roewe",
    "Rolls-Royce",
    "Romania",
    "Rosenbauer",
    "Rosengart",
    "Rossion",
    "Royal Enfield Brasil",
    "Royal Star",
    "Ruf",
    "Runner Automobiles",
    "Russia",
    "Rába",
    "SAIC Motor",
    "SAIPA",
    "SEAT",
    "SIN Cars",
    "SSC",
    "STI",
    "Saab",
    "Saehan",
    "Saenara",
    "Saker",
    "Saleen",
    "Salmson",
    "SamKochAvto",
    "Santana",
    "Sao",
    "Saturn",
    "Savage Rivale",
    "Saviem",
    "Sazgar",
    "Scania",
    "Scavas",
    "Scion",
    "Scuderia Cameron Glickenhaus",
    "Senova",
    "Serbia",
    "Seres",
    "Shaanxi Automobile Group",
    "Shahab Khodro",
    "Shaka",
    "Shamrock",
    "Shanghai Maple Guorun Automobile",
    "Shelby American",
    "Shineray do Brasil",
    "Shinjin",
    "Shrike",
    "Shuanghuan",
    "Siata",
    "Sichuan Tengzhong",
    "Simca",
    "Simca do Brasil",
    "Sisu Auto",
    "SlovBus",
    "Slovakia",
    "Smart",
    "Sofia",
    "Sollers",
    "Soueast",
    "Soueast Motors",
    "Spania GTA",
    "Spartan",
    "Spartan Motor Company",
    "Speranza",
    "Spirra",
    "Springuel",
    "Spyker",
    "Ssangyong",
    "Standard",
    "Startup",
    "Statesman",
    "Staver",
    "Stearns-Knight",
    "Steel Brothers",
    "Stelato",
    "Stelka",
    "Stellantis",
    "Steyr Motors GmbH",
    "Steyr automobile",
    "Steyr-Daimler-Puch",
    "Stohr Cars",
    "Studebaker",
    "Styl Kar",
    "Subaru",
    "Sunbeam",
    "Sunbeam-Talbot",
    "Sundown Motos",
    "Sungri Motors",
    "Superformance",
    "Suzuki",
    "Swallow",
    "Sweden",
    "TAC",
    "TAM",
    "TANK",
    "TAV",
    "TAZ",
    "TD2000",
    "THACO",
    "TMC Costin",
    "TOGG",
    "TVR",
    "TagAZ",
    "Taiwan",
    "Takeoka Auto Craft",
    "Talbot",
    "Talbot-Lago",
    "Tangalakis",
    "Tarrant",
    "Tarso Marques",
    "Tata Motors",
    "Tatra",
    "Tauro Sport Auto",
    "TechArt",
    "Techrules",
    "Tecnologia Automotiva Catarinense",
    "Temsa",
    "Tesla",
    "Thai Rung",
    "Thailand",
    "Theologou",
    "Think",
    "Thunder Power",
    "Timeline of motor vehicle brands",
    "Timmis",
    "Timor",
    "Tjorven",
    "Tofaş",
    "Tornado",
    "Toroidion",
    "Toyopet",
    "Toyota",
    "Toyota Canada",
    "Trabant",
    "Tracta",
    "Tramontana (sports car)",
    "Trekka",
    "Trident",
    "Trion Supercars",
    "Triumph",
    "Triumph Brazil",
    "Trnavské automobilové závody",
    "Trojan",
    "Troliga Bus",
    "Troll",
    "Troller",
    "Truck manufacturers",
    "Trumpchi",
    "Tudhope",
    "Turkey",
    "Turner",
    "Tushek & Spigel",
    "Tushek & Spigel Supercars",
    "Tyrrell",
    "UAZ",
    "UD Trucks",
    "Uri-Automobile",
    "Uttara",
    "UzAuto Motors",
    "VAM",
    "VDL Nedcar",
    "VELAM",
    "VLEGA Gaucho",
    "VW-Porsche",
    "Valmet Automotive",
    "Valtra",
    "Van Doorne's Automobiel Fabrieken",
    "Vanaja",
    "Vanden Plas",
    "Vauxhall",
    "Vector",
    "Vehicle Production Group",
    "Velorex",
    "Vencer",
    "Venturi",
    "Venucia",
    "Vespa",
    "Viação Itapemirim",
    "Vicinity Motor Corp.",
    "Vietnam",
    "VinFast",
    "Vinaxuki",
    "Vincke",
    "Vivinus",
    "Voisin",
    "Volkswagen",
    "Volkswagen aka VWB",
    "Volkswagen do Brasil",
    "Voltz Motors",
    "Volvo",
    "Volvo Cars",
    "Voyah",
    "W Motors",
    "Wallyscar",
    "Walter",
    "Walton Motors",
    "Wanderer",
    "Wartburg",
    "Warwick",
    "Western Star",
    "Wey",
    "Wheego",
    "Whirlpool",
    "Wiesmann",
    "Wikov",
    "Willys",
    "Wolseley",
    "Wood",
    "Wuling",
    "XPeng",
    "Xiaomi Auto",
    "Xinkai",
    "Yamaha",
    "Yamaha Motor",
    "Yamaha Motor Pakistan",
    "Yangwang",
    "Yema Auto",
    "Youngman",
    "Yue Long/Yulon/YLN",
    "Yuejin",
    "Yugo",
    "Yusheng",
    "Yutong",
    "ZENN",
    "ZX Auto",
    "Zacua",
    "Zagross Khodro",
    "Zanella",
    "Zastava",
    "Zastava TERVO",
    "Zbrojovka Brno",
    "Zeekr",
    "Zenvo Automotive",
    "Zeta",
    "ZiL",
    "Zimmer",
    "Zotye",
    "Bucciali",
    "Ducati",
    "Hispano-Suiza",
    "Richard-Brasier",
    "RUF",
    "Marmon",
    "Niclausse",
    "Laverda",
    "G.A.R",
    "Citroen",
    "Turcat-MÃ©ry",
    "Delaunay-Belleville",
    "Prunel",
    "Decauville",
    "Bedelia",
    "Sizaire-FrÃ¨res",
    "Altos Moto",
    "Honda",
    "Shelby",
]

# %%
import pandas as pd

# %%
file = "broadarrowauction/final/broadarrowauction_2024.csv"
df = pd.read_csv(file)
df.head()
# Out:
#                                                Title Sold Status  \
# 0                 1957 Mercedes-Benz 300 SL Roadster   $995,000
# 1                             1996 Porsche 911 Turbo        Sold
# 2  1901 Panhard et Levassor Twin-Cylinder 7 HP Re...        Sold
# 3                              1972 DeTomaso Panther        Sold
# 4                             1987 Porsche 911 Turbo        Sold
#
#                                               info_0  \
# 0  One of only 30 300 SL Roadsters originally fin...
# 1  Classically finished in Polar Silver Metallic ...
# 2  Multiple time London-to-Brighton Veteran Car R...
# 3  Offered with 29,382 miles at time of catalogin...
# 4  Incredible “time-capsule” condition, unmodifie...
#
#                                               info_1  \
# 0  Retains its original numbers-matching chassis,...
# 1  Optioned with heated Black leather sport seats...
# 2          Accompanied by its VCC Dating Certificate
# 3  Delivered in Red over a Black upholstered inte...
# 4  A matching numbers investment grade example wi...
#
#                                               info_2  \
# 0  The recipient of a comprehensive older restora...
# 1  Offered with its factory-issued books and manu...
# 2  Attractive, original tonneau coachwork by Henr...
# 3  Upgrades include a Centerforce clutch and flyw...
# 4  Recent servicing includes four new tires, an o...
#
#                                               info_3  \
# 0  Benefits from over $30,000 in service work com...
# 1  3.6-liter twin-turbo flat-six producing 400 ho...
# 2     Early, highly desirable UK registration “A 72”
# 3  Includes Deluxe Marti Report, owner's manual, ...
# 4  A “Tourist Delivery” example optioned with hea...
#
#                                               info_4           Event Date  \
# 0                  First year of Roadster production  14 - 15 August 2024
# 1  The final air-cooled 911 Turbo, the first with...  14 - 15 August 2024
# 2  Twin-cylinder, 1,650 cc engine offering seven ...  14 - 15 August 2024
# 3  An attractive pre-impact bumper example of the...  14 - 15 August 2024
# 4  Offered with its toolkit, Porsche-issued Certi...  14 - 15 August 2024
#
#                                          orginal_URL      Price  \
# 0  https://www-broadarrowauctions-com.translate.g...        NaN
# 1  https://www-broadarrowauctions-com.translate.g...  $246,400
# 2  https://www-broadarrowauctions-com.translate.g...  $307,500
# 3  https://www-broadarrowauctions-com.translate.g...   $75,040
# 4  https://www-broadarrowauctions-com.translate.g...  $252,000
#
#                                               info_5  \
# 0                                                NaN
# 1                                                NaN
# 2  Chain drive with a three-speed gearbox and mag...
# 3                                                NaN
# 4                                                NaN
#
#                                               info_6 info_7 info_8  \
# 0                                                NaN    NaN    NaN
# 1                                                NaN    NaN    NaN
# 2  Recently serviced by Chris Kidd's Tired Iron W...    NaN    NaN
# 3                                                NaN    NaN    NaN
# 4                                                NaN    NaN    NaN
#
#                                          listing_URL info_9
# 0  https://www.broadarrowauctions.com/vehicles/jc...    NaN
# 1  https://www.broadarrowauctions.com/vehicles/jc...    NaN
# 2  https://www.broadarrowauctions.com/vehicles/jc...    NaN
# 3  https://www.broadarrowauctions.com/vehicles/jc...    NaN
# 4  https://www.broadarrowauctions.com/vehicles/jc...    NaN

# %%
df.columns
# Out:
# Index(['Title', 'Sold Status', 'info_0', 'info_1', 'info_2', 'info_3',
#        'info_4', 'Event Date', 'orginal_URL', 'Price', 'info_5', 'info_6',
#        'info_7', 'info_8', 'listing_URL', 'info_9'],
#       dtype='object')

# %%
null_rows_specific = df[df["Title"].isnull()]
print(null_rows_specific["orginal_URL"])
# Out:
# Series([], Name: orginal_URL, dtype: object)

# %%
sentences = df["Title"]

# %%
len(sentences)
# Out:
# 457

# %%
import re


def find_brands_in_sentence(sentence, brand_name):
    matches = []
    for brand in brand_name:
        # Find all occurrences of the brand in the sentence
        match = re.findall(rf"\b{re.escape(brand)}\b", sentence)
        if match:
            matches.extend(match)  # Add the matched brand to the list
    return matches[0] if matches else ""

# %%
total = []
for sentence in sentences:
    if isinstance(sentence, str):
        # Call the function and print the result
        result = find_brands_in_sentence(sentence, brand_name)
        total.append(result)
    else:
        print(sentence)
        total.append("")

# %%
len(total)
# Out:
# 457

# %%
df["Make"] = total

# %%
pattern = r"\b\d{4}\b"
final_year = []
for sentence in sentences:
    match = re.search(pattern, sentence)

    # Extracted year
    if match:
        # print(match.group(0))
        year = match.group(0)
    else:
        year = ""
    final_year.append(year)

# %%
len(final_year)
# Out:
# 457

# %%
df["Year"] = final_year

# %%
test_d = df[["Title", "Make"]]

# %%
model_final = []
for idx, (Title, Make) in enumerate(zip(test_d["Title"], test_d["Make"])):
    if Make:
        pattern = rf"\b{re.escape(Make)}\b"
        parts = re.split(pattern, Title)
        model_final.append(parts[1])
    else:
        model_final.append("")

# %%
len(model_final)
# Out:
# 457

# %%
df["Model"] = model_final

# %%
df.columns
# Out:
# Index(['Title', 'Sold Status', 'info_0', 'info_1', 'info_2', 'info_3',
#        'info_4', 'Event Date', 'orginal_URL', 'Price', 'info_5', 'info_6',
#        'info_7', 'info_8', 'listing_URL', 'info_9', 'Make', 'Year', 'Model'],
#       dtype='object')

# %%
# Function to extract currency
def extract_currency(price):
    price = str(price)
    if "$" in price:
        return "USD"
    elif "€" in price:
        return "EUR"
    elif "£" in price:
        return "GBP"
    elif "₹" in price:
        return "INR"
    else:
        return "Unknown"

# %%
df["Currency"] = df["Price"].apply(extract_currency)

# %%
df.head()
# Out:
#                                                Title Sold Status  \
# 0                 1957 Mercedes-Benz 300 SL Roadster   $995,000
# 1                             1996 Porsche 911 Turbo        Sold
# 2  1901 Panhard et Levassor Twin-Cylinder 7 HP Re...        Sold
# 3                              1972 DeTomaso Panther        Sold
# 4                             1987 Porsche 911 Turbo        Sold
#
#                                               info_0  \
# 0  One of only 30 300 SL Roadsters originally fin...
# 1  Classically finished in Polar Silver Metallic ...
# 2  Multiple time London-to-Brighton Veteran Car R...
# 3  Offered with 29,382 miles at time of catalogin...
# 4  Incredible “time-capsule” condition, unmodifie...
#
#                                               info_1  \
# 0  Retains its original numbers-matching chassis,...
# 1  Optioned with heated Black leather sport seats...
# 2          Accompanied by its VCC Dating Certificate
# 3  Delivered in Red over a Black upholstered inte...
# 4  A matching numbers investment grade example wi...
#
#                                               info_2  \
# 0  The recipient of a comprehensive older restora...
# 1  Offered with its factory-issued books and manu...
# 2  Attractive, original tonneau coachwork by Henr...
# 3  Upgrades include a Centerforce clutch and flyw...
# 4  Recent servicing includes four new tires, an o...
#
#                                               info_3  \
# 0  Benefits from over $30,000 in service work com...
# 1  3.6-liter twin-turbo flat-six producing 400 ho...
# 2     Early, highly desirable UK registration “A 72”
# 3  Includes Deluxe Marti Report, owner's manual, ...
# 4  A “Tourist Delivery” example optioned with hea...
#
#                                               info_4           Event Date  \
# 0                  First year of Roadster production  14 - 15 August 2024
# 1  The final air-cooled 911 Turbo, the first with...  14 - 15 August 2024
# 2  Twin-cylinder, 1,650 cc engine offering seven ...  14 - 15 August 2024
# 3  An attractive pre-impact bumper example of the...  14 - 15 August 2024
# 4  Offered with its toolkit, Porsche-issued Certi...  14 - 15 August 2024
#
#                                          orginal_URL      Price  \
# 0  https://www-broadarrowauctions-com.translate.g...        NaN
# 1  https://www-broadarrowauctions-com.translate.g...  $246,400
# 2  https://www-broadarrowauctions-com.translate.g...  $307,500
# 3  https://www-broadarrowauctions-com.translate.g...   $75,040
# 4  https://www-broadarrowauctions-com.translate.g...  $252,000
#
#                                               info_5  \
# 0                                                NaN
# 1                                                NaN
# 2  Chain drive with a three-speed gearbox and mag...
# 3                                                NaN
# 4                                                NaN
#
#                                               info_6 info_7 info_8  \
# 0                                                NaN    NaN    NaN
# 1                                                NaN    NaN    NaN
# 2  Recently serviced by Chris Kidd's Tired Iron W...    NaN    NaN
# 3                                                NaN    NaN    NaN
# 4                                                NaN    NaN    NaN
#
#                                          listing_URL info_9           Make  \
# 0  https://www.broadarrowauctions.com/vehicles/jc...    NaN  Mercedes-Benz
# 1  https://www.broadarrowauctions.com/vehicles/jc...    NaN        Porsche
# 2  https://www.broadarrowauctions.com/vehicles/jc...    NaN        Panhard
# 3  https://www.broadarrowauctions.com/vehicles/jc...    NaN        Panther
# 4  https://www.broadarrowauctions.com/vehicles/jc...    NaN        Porsche
#
#    Year                                              Model Currency
# 0  1957                                    300 SL Roadster  Unknown
# 1  1996                                          911 Turbo      USD
# 2  1901   et Levassor Twin-Cylinder 7 HP Rear Entrance ...      USD
# 3  1972                                                         USD
# 4  1987                                          911 Turbo      USD

# %%
# Function to clean price and extract only numbers
def clean_price(price):
    if pd.isna(price):  # Check if value is NaN
        return None
    price = str(price)  # Convert to string for processing
    price = re.sub(r"[^\d.]", "", price)  # Remove all non-numeric characters except '.'
    return float(price) if price else None  # Convert to float

# %%
df["Price"] = df["Price"].apply(clean_price)

# %%
df.head()
# Out:
#                                                Title Sold Status  \
# 0                 1957 Mercedes-Benz 300 SL Roadster   $995,000
# 1                             1996 Porsche 911 Turbo        Sold
# 2  1901 Panhard et Levassor Twin-Cylinder 7 HP Re...        Sold
# 3                              1972 DeTomaso Panther        Sold
# 4                             1987 Porsche 911 Turbo        Sold
#
#                                               info_0  \
# 0  One of only 30 300 SL Roadsters originally fin...
# 1  Classically finished in Polar Silver Metallic ...
# 2  Multiple time London-to-Brighton Veteran Car R...
# 3  Offered with 29,382 miles at time of catalogin...
# 4  Incredible “time-capsule” condition, unmodifie...
#
#                                               info_1  \
# 0  Retains its original numbers-matching chassis,...
# 1  Optioned with heated Black leather sport seats...
# 2          Accompanied by its VCC Dating Certificate
# 3  Delivered in Red over a Black upholstered inte...
# 4  A matching numbers investment grade example wi...
#
#                                               info_2  \
# 0  The recipient of a comprehensive older restora...
# 1  Offered with its factory-issued books and manu...
# 2  Attractive, original tonneau coachwork by Henr...
# 3  Upgrades include a Centerforce clutch and flyw...
# 4  Recent servicing includes four new tires, an o...
#
#                                               info_3  \
# 0  Benefits from over $30,000 in service work com...
# 1  3.6-liter twin-turbo flat-six producing 400 ho...
# 2     Early, highly desirable UK registration “A 72”
# 3  Includes Deluxe Marti Report, owner's manual, ...
# 4  A “Tourist Delivery” example optioned with hea...
#
#                                               info_4           Event Date  \
# 0                  First year of Roadster production  14 - 15 August 2024
# 1  The final air-cooled 911 Turbo, the first with...  14 - 15 August 2024
# 2  Twin-cylinder, 1,650 cc engine offering seven ...  14 - 15 August 2024
# 3  An attractive pre-impact bumper example of the...  14 - 15 August 2024
# 4  Offered with its toolkit, Porsche-issued Certi...  14 - 15 August 2024
#
#                                          orginal_URL     Price  \
# 0  https://www-broadarrowauctions-com.translate.g...       NaN
# 1  https://www-broadarrowauctions-com.translate.g...  246400.0
# 2  https://www-broadarrowauctions-com.translate.g...  307500.0
# 3  https://www-broadarrowauctions-com.translate.g...   75040.0
# 4  https://www-broadarrowauctions-com.translate.g...  252000.0
#
#                                               info_5  \
# 0                                                NaN
# 1                                                NaN
# 2  Chain drive with a three-speed gearbox and mag...
# 3                                                NaN
# 4                                                NaN
#
#                                               info_6 info_7 info_8  \
# 0                                                NaN    NaN    NaN
# 1                                                NaN    NaN    NaN
# 2  Recently serviced by Chris Kidd's Tired Iron W...    NaN    NaN
# 3                                                NaN    NaN    NaN
# 4                                                NaN    NaN    NaN
#
#                                          listing_URL info_9           Make  \
# 0  https://www.broadarrowauctions.com/vehicles/jc...    NaN  Mercedes-Benz
# 1  https://www.broadarrowauctions.com/vehicles/jc...    NaN        Porsche
# 2  https://www.broadarrowauctions.com/vehicles/jc...    NaN        Panhard
# 3  https://www.broadarrowauctions.com/vehicles/jc...    NaN        Panther
# 4  https://www.broadarrowauctions.com/vehicles/jc...    NaN        Porsche
#
#    Year                                              Model Currency
# 0  1957                                    300 SL Roadster  Unknown
# 1  1996                                          911 Turbo      USD
# 2  1901   et Levassor Twin-Cylinder 7 HP Rear Entrance ...      USD
# 3  1972                                                         USD
# 4  1987                                          911 Turbo      USD

# %%
df.columns
# Out:
# Index(['Title', 'Sold Status', 'info_0', 'info_1', 'info_2', 'info_3',
#        'info_4', 'Event Date', 'orginal_URL', 'Price', 'info_5', 'info_6',
#        'info_7', 'info_8', 'listing_URL', 'info_9', 'Make', 'Year', 'Model',
#        'Currency'],
#       dtype='object')

# %%
new_order = [
    "Title",
    "Year",
    "Make",
    "Model",
    "Sold Status",
    "Price",
    "Currency",
    "info_0",
    "info_1",
    "info_2",
    "info_3",
    "info_4",
    "info_5",
    "info_6",
    "info_7",
    "info_8",
    "info_9",
    #"info_10",
    #"info_11",
    "Event Date",
    "listing_URL",
]

# %%
data_new_order = df[new_order]

# %%
data_new_order.to_csv(
    "broadarrowauction/final_clean/broadarrowauction_2024_final.csv",
    index=False,
)
